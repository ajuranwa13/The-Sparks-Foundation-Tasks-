# %% [markdown]
# # The Sparks Foundation #GRIPMAY2021

# %% [markdown]
# ## Task :- Prediction using Supervised ML

# %% [markdown]
# ### by :- Ajay Ranwa

# %%
#import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read csv file
df = pd.read_csv('Student_data.csv')

# %%
# show data frame top 10 values
df.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
x = df.iloc[:,0] # second column of data frame (Hours)
y = df.iloc[:,-1] # last column of data frame (Scores)

# %%
# ploting the data in scatter graph befor testing
plt.scatter(x,y,color='Blue')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()
